# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
import os
import warnings
warnings.filterwarnings("ignore")

# %%
train_dir = r"E:\AI\Covid19-dataset\train"
test_dir = r"E:\AI\Covid19-dataset\test"

# %%
img_width, img_height = 512, 512

# %%
batch_size = 32

# %%
train_dataset = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
test_dataset = ImageDataGenerator(rescale=1./255)

# %%
X_train = train_dataset.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical"
)
# Out:
# Found 251 images belonging to 3 classes.

# %%
X_test = test_dataset.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical"
)
# Out:
# Found 58 images belonging to 3 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(img_width, img_height, 3)),
    MaxPool2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPool2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPool2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPool2D((2, 2)),
    Flatten(),
    Dense(512, activation="relu"),
    Dense(256, activation="relu"),
    Dense(3, activation="softmax")
])

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(X_train, epochs=30, validation_data=X_test)
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 392s 47s/step - accuracy: 0.3404 - loss: 2.7590 - val_accuracy: 0.5690 - val_loss: 1.1007
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 365s 42s/step - accuracy: 0.5953 - loss: 1.0201 - val_accuracy: 0.2931 - val_loss: 1.4301
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 359s 42s/step - accuracy: 0.6341 - loss: 0.8095 - val_accuracy: 0.5345 - val_loss: 1.7386
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 302s 35s/step - accuracy: 0.7198 - loss: 0.6022 - val_accuracy: 0.6897 - val_loss: 1.4528
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 299s 35s/step - accuracy: 0.6809 - loss: 0.9083 - val_accuracy: 0.5517 - val_loss: 1.0567
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 268s 31s/step - accuracy: 0.7024 - loss: 0.6853 - val_accuracy: 0.6034 - val_loss: 1.0513
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 301s 38s/step - accuracy: 0.7233 - loss: 0.6369 - val_accuracy: 0.5345 - val_loss: 1.2373
# Epoch 8/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 285s 32s/step - accuracy: 0.7871 - loss: 0.5309 - val_accuracy: 0.5690 - val_loss: 1.2704
# Epoch 9/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 252s 29s/step - accuracy: 0.8286 - loss: 0.4257 - val_accuracy: 0.5862 - val_loss: 1.1249
# Epoch 10/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 258s 30s/step - accuracy: 0.7901 - loss: 0.5025 - val_accuracy: 0.5690 - val_loss: 0.9169
# Epoch 11/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 268s 32s/step - accuracy: 0.8552 - loss: 0.4535 - val_accuracy: 0.5345 - val_loss: 0.8443
# Epoch 12/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 324s 37s/step - accuracy: 0.8775 - loss: 0.3798 - val_accuracy: 0.6207 - val_loss: 0.8339
# Epoch 13/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 331s 40s/step - accuracy: 0.7863 - loss: 0.4614 - val_accuracy: 0.6552 - val_loss: 1.0390
# Epoch 14/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 323s 40s/step - accuracy: 0.7858 - loss: 0.6447 - val_accuracy: 0.6552 - val_loss: 0.7656
# Epoch 15/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 295s 35s/step - accuracy: 0.8101 - loss: 0.5292 - val_accuracy: 0.6552 - val_loss: 0.6707
# Epoch 16/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 283s 33s/step - accuracy: 0.8104 - loss: 0.4605 - val_accuracy: 0.6552 - val_loss: 0.6999
# Epoch 17/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 275s 32s/step - accuracy: 0.8301 - loss: 0.4169 - val_accuracy: 0.6724 - val_loss: 0.8152
# Epoch 18/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 265s 32s/step - accuracy: 0.8247 - loss: 0.4287 - val_accuracy: 0.6897 - val_loss: 0.6969
# Epoch 19/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 278s 31s/step - accuracy: 0.8613 - loss: 0.3647 - val_accuracy: 0.7069 - val_loss: 0.7005
# Epoch 20/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 302s 34s/step - accuracy: 0.8573 - loss: 0.3810 - val_accuracy: 0.7069 - val_loss: 0.6673
# Epoch 21/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 342s 43s/step - accuracy: 0.8413 - loss: 0.4017 - val_accuracy: 0.6724 - val_loss: 0.6313
# Epoch 22/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 400s 46s/step - accuracy: 0.8912 - loss: 0.3065 - val_accuracy: 0.6897 - val_loss: 0.7923
# Epoch 23/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 461s 54s/step - accuracy: 0.8865 - loss: 0.3502 - val_accuracy: 0.6897 - val_loss: 1.0752
# Epoch 24/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 409s 49s/step - accuracy: 0.8885 - loss: 0.2673 - val_accuracy: 0.6724 - val_loss: 0.7863
# Epoch 25/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 424s 48s/step - accuracy: 0.8629 - loss: 0.3304 - val_accuracy: 0.6379 - val_loss: 0.7503
# Epoch 26/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 409s 51s/step - accuracy: 0.8928 - loss: 0.3045 - val_accuracy: 0.7241 - val_loss: 0.6677
# Epoch 27/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 361s 41s/step - accuracy: 0.8941 - loss: 0.2585 - val_accuracy: 0.7414 - val_loss: 0.6023
# Epoch 28/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 367s 41s/step - accuracy: 0.8916 - loss: 0.3095 - val_accuracy: 0.7586 - val_loss: 0.6921
# Epoch 29/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 366s 43s/step - accuracy: 0.8890 - loss: 0.3210 - val_accuracy: 0.7586 - val_loss: 0.6167
# Epoch 30/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 378s 45s/step - accuracy: 0.9055 - loss: 0.2299 - val_accuracy: 0.8276 - val_loss: 0.5298

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# %%
class_labels = X_train.class_indices

# %%
class_names = {value: key for key, value in class_labels.items()}
print("Class Names:", class_names)
# Out:
# Class Names: {0: 'Covid', 1: 'Normal', 2: 'Viral Pneumonia'}

# %%
from tensorflow.keras.preprocessing import image

# %%
img_path = r"E:\AI\Covid19-dataset\test\Covid\radiopaedia-2019-novel-coronavirus-infected-pneumonia.jpg"

# %%
img = image.load_img(img_path, target_size=(img_width, img_height))

# %%
img_arr = image.img_to_array(img)

# %%
img_arr = np.expand_dims(img_arr, axis=0)

# %%
img_arr = img_arr / 255.0

# %%
pred = model.predict(img_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step

# %%
pred_class = np.argmax(pred)

# %%
class_names[pred_class]
# Out:
# 'Covid'
